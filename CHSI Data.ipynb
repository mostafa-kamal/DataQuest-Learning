# %% [markdown]
# ## CHSI Data

# %%
import pandas as pd
cause_of_death = pd.read_csv('/home/mostafa/Downloads/chsi_dataset/LEADINGCAUSESOFDEATH.csv')
cause_of_death[:2]
# Out:
#    State_FIPS_Code  County_FIPS_Code CHSI_County_Name CHSI_State_Name  \
# 0                1                 1          Autauga         Alabama
# 1                1                 3          Baldwin         Alabama
#
#   CHSI_State_Abbr  Strata_ID_Number  A_Wh_Comp  CI_Min_A_Wh_Comp  \
# 0              AL                29      -1111             -1111
# 1              AL                16         57                39
#
#    CI_Max_A_Wh_Comp  A_Bl_Comp      ...        F_Bl_Cancer  \
# 0             -1111      -1111      ...                 19
# 1                75      -1111      ...                 20
#
#    CI_Min_F_Bl_Cancer  CI_Max_F_Bl_Cancer  F_Ot_Cancer  CI_Min_F_Ot_Cancer  \
# 0                  14                  23        -1111               -1111
# 1                  15                  25        -1111               -1111
#
#    CI_Max_F_Ot_Cancer  F_Hi_Cancer  CI_Min_F_Hi_Cancer  CI_Max_F_Hi_Cancer  \
# ...

# %%
column_list = list(cause_of_death.columns)
column_list
# Out:
# ['State_FIPS_Code',
#  'County_FIPS_Code',
#  'CHSI_County_Name',
#  'CHSI_State_Name',
#  'CHSI_State_Abbr',
#  'Strata_ID_Number',
#  'A_Wh_Comp',
#  'CI_Min_A_Wh_Comp',
#  'CI_Max_A_Wh_Comp',
#  'A_Bl_Comp',
#  'CI_Min_A_Bl_Comp',
#  'CI_Max_A_Bl_Comp',
#  'A_Ot_Comp',
#  'CI_Min_A_Ot_Comp',
#  'CI_Max_A_Ot_Comp',
#  'A_Hi_Comp',
#  'CI_Min_A_Hi_Comp',
#  'CI_Max_A_Hi_Comp',
#  'A_Wh_BirthDef',
#  'CI_Min_A_Wh_BirthDef',
#  'CI_Max_A_Wh_BirthDef',
#  'A_Bl_BirthDef',
#  'CI_Min_A_Bl_BirthDef',
#  'CI_Max_A_Bl_BirthDef',
#  'A_Ot_BirthDef',
#  'CI_Min_A_Ot_BirthDef',
#  'CI_Max_A_Ot_BirthDef',
#  'A_Hi_BirthDef',
#  'CI_Min_A_Hi_BirthDef',
#  'CI_Max_A_Hi_BirthDef',
#  'B_Wh_Injury',
#  'CI_Min_B_Wh_Injury',
#  'CI_Max_B_Wh_Injury',
#  'B_Bl_Injury',
#  'CI_Min_B_Bl_Injury',
#  'CI_Max_B_Bl_Injury',
#  'B_Ot_Injury',
#  'CI_Min_B_Ot_Injury',
#  'CI_Max_B_Ot_Injury',
#  'B_Hi_Injury',
#  'CI_Min_B_Hi_Injury',
#  'CI_Max_B_Hi_Injury',
#  'B_Wh_Cancer',
#  'CI_Min_B_Wh_Cancer',
# ...
